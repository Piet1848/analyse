# %% [markdown]
# # Detailed Analysis & Debugging Notebook
#
# This notebook provides a step-by-step breakdown of the lattice QCD analysis pipeline. It allows you to inspect the data, visualize the fits, and tune parameters for `r0` and `r0_chi` extraction.
#
# ## Instructions
# 1. Set the **Data Path** and **Parameters** in the "Configuration" section.
# 2. Run the cells sequentially to initialize data.
# 3. Use the **Interactive Dashboard** at the end to visualize and debug calculations.

# %%
beso
import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as widgets

# Local modules
import data_organizer as do
from calculator import Calculator

# Setup plotting style
plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12

# %%
# --- CONFIGURATION ---

# 1. Data Path 
FILE_PATH = "../data/20260205/36"

# 2. Analysis Parameters
THERMALIZATION_STEPS = 500
SOMMER_TARGET_FORCE = 1.65

# 3. Interactive Defaults
R0_CHI_T_LARGE = 4
CHI_FIT_WINDOW = 2

print(f"Analyzing Directory: {FILE_PATH}")
print(f"Parameters: Therm={THERMALIZATION_STEPS}, Target={SOMMER_TARGET_FORCE}")

# %% [markdown]
# ## 1. Load Data and Thermalization
#
# We load the raw data using `data_organizer`. We then strip the initial thermalization steps.

# %%
# Initialize Experiment Data
try:
    experiment = do.ExperimentData(FILE_PATH)
    print(f"Loaded experiment data from {FILE_PATH}")
    
    # We expect a file like 'W_temp.out' or similar which contains the Wilson loops
    target_file = "W_temp"
    if target_file not in experiment.data and experiment.data:
        target_file = list(experiment.data.keys())[0]
        print(f"Warning: 'W_temp' not found. Using '{target_file}' instead.")
    
    if target_file in experiment.data:
        file_data = experiment.data[target_file][0]
        print(f"Selected file: {file_data.name} with {len(file_data.observables[0].values)} entries.")
        
        # Remove Thermalization
        step_obs = next((o for o in file_data.observables if o.name in ["# step", "step"]), None)
        if step_obs:
            steps = np.array(step_obs.values)
            mask = steps >= THERMALIZATION_STEPS
            if np.sum(mask) < len(steps):
                 print(f"Removing thermalization (step < {THERMALIZATION_STEPS}). Keeping {np.sum(mask)}/{len(steps)} configurations.")
                 for obs in file_data.observables:
                     obs.values = np.array(obs.values)[mask].tolist()
        else:
             print("Warning: No step column found. Cannot remove thermalization.")
             
    else:
        print("Error: No valid data files found.")
        file_data = None

except Exception as e:
    print(f"Failed to load data: {e}")
    file_data = None

# %%
if file_data:
    # Initialize Calculator
    calc = Calculator(file_data, n_bootstrap=50, step_size=1)
    print("Calculator initialized.")
    
    # Placeholder for metro_params (used in plot titles)
    # If you have a way to load these from a file, add it here.
    metro_params = None
else:
    print("Calculator not initialized due to missing data.")
    calc = None
    metro_params = None

# %% [markdown]
# ## 2. Creutz Ratios $\chi(R, T)$ and $r_{0,\chi}$
#
# We calculate the Creutz ratios to extract the force directly without fitting a potential.
# $$ \chi(R, T) \approx a^2 F(R) $$
# We extract the force at a large time $T$.
# Then we interpolate $r^2 F(r)$ to find $r_{0,\chi}$.
#
# **Adjust parameters below.**

# %%
# Interactive Creutz Ratio Analysis
def interact_creutz(t_large, target_force, fit_window):
    if not file_data: return

    # 1. Calculate F_chi(R)
    unique_Ls = sorted(np.unique(file_data.get("L").values))
    chi_Rs = [L + 0.5 for L in unique_Ls if L+1 in unique_Ls]
    
    f_chis = []
    f_errs = []
    valid_rs = []
    
    for r in chi_Rs:
        try:
            f_var = calc.get_variable("F_chi", R=r, t_large=t_large)
            val = f_var.get()
            err = f_var.err()
            if not np.isnan(val) and val > 0 and err/val < 0.5:
                f_chis.append(val)
                f_errs.append(err)
                valid_rs.append(r)
        except: continue
        
    valid_rs = np.array(valid_rs)
    f_chis = np.array(f_chis)
    f_errs = np.array(f_errs)
    
    if len(valid_rs) == 0:
        print("No valid Creutz ratios found.")
        return

    # 2. Calculate r0_chi
    try:
        r0c_var = calc.get_variable("r0_chi", t_large=t_large, target_force=target_force, fit_window=fit_window)
        r0c_val = r0c_var.get()
        r0c_err = r0c_var.err()
        
        print(f"r0_chi for T={t_large}, Target={target_force}:")
        print(f"r0_chi = {r0c_val:.4f} +/- {r0c_err:.4f}")
        
        # PLOTS
        fig, axes = plt.subplots(1, 2, figsize=(14, 6))
        
        if metro_params:
            fig.suptitle(f"beta={metro_params.beta}, L0={metro_params.L0}, eps1={metro_params.epsilon1}")
        
        # Force F(R)
        ax = axes[0]
        ax.errorbar(valid_rs, f_chis, yerr=f_errs, fmt='o', label='Creutz F(R)')
        ax.set_title(f"Creutz Force F(R) at T={t_large}")
        ax.set_xlabel("R")
        ax.set_ylabel("F(R)")
        ax.set_yscale('log')
        ax.legend()
        
        # r^2 F(r) Interpolation
        ax = axes[1]
        r2f = (valid_rs**2) * f_chis
        r2f_err = (valid_rs**2) * f_errs
        
        ax.errorbar(valid_rs, r2f, yerr=r2f_err, fmt='o', label=r'$r^2 \chi(r)$')
        ax.axhline(target_force, color='k', linestyle='--', label=f'Target = {target_force}')
        
        if not np.isnan(r0c_val):
             ax.axvline(r0c_val, color='g', linestyle='--', label=f'r0_chi = {r0c_val:.3f}')
        
        ax.set_title("Creutz Scale Determination")
        ax.set_xlabel("R")
        ax.set_ylabel("$r^2 F(r)$")
        ax.legend()
        
        plt.tight_layout()
        plt.show()

    except Exception as e:
        print(f"Error: {e}")

if file_data:
    widgets.interact(interact_creutz,
                     t_large=widgets.IntSlider(min=2, max=10, step=1, value=R0_CHI_T_LARGE),
                     target_force=widgets.FloatSlider(min=1.0, max=2.0, step=0.05, value=SOMMER_TARGET_FORCE),
                     fit_window=widgets.IntSlider(min=1, max=4, step=1, value=CHI_FIT_WINDOW))

# %% [markdown]
# ## Creutz Physical Ratio P(R)
#
# Here we calculate the physical ratio $P(R)$ defined by Creutz:
# $$ P(R) = 1 - \frac{W(R,R) W(R/2,R/2)}{W(R,R/2)^2} $$
#
# This quantity is designed to be free of perimeter and corner divergences.

# %%
def analyze_creutz_P():
    if not 'calc' in globals():
        print("Calculator not initialized. Please run previous cells.")
        return

    # Try even R values
    rs = []
    p_vals = []
    p_errs = []

    print("Calculating Creutz P(R):")
    for R in range(2, 13, 2): # 2, 4, 6,
        try:
            # We need W(R,R), W(R/2,R/2), W(R, R/2)
            # The calculator handles the retrieval.
            p_var = calc.get_variable("creutz_P", R=R)
            val = p_var.get()
            err = p_var.err()
            
            if val is not None and not np.isnan(val):
                print(f"R={R}: P = {val:.6f} +/- {err:.6f}")
                rs.append(R)
                p_vals.append(val)
                p_errs.append(err if err is not None else 0.0)
            else:
                 print(f"R={R}: Result is NaN or None")

        except Exception as e:
            # Likely missing Wilson loops for large R
            print(f"R={R}: Could not calculate ({e})")
    
    if not rs:
        print("No P(R) values could be calculated.")
        return

    # Plot
    plt.figure(figsize=(8, 6))
    plt.errorbar(rs, p_vals, yerr=p_errs, fmt='o-', capsize=5, label='P(R)')
    
    title_str = "Creutz Physical Ratio P(R)"
    if metro_params:
         title_str += f"\n(beta={metro_params.beta}, L0={metro_params.L0}, eps1={metro_params.epsilon1})"
    plt.title(title_str)
    
    plt.xlabel("R (lattice units)")
    plt.ylabel("P(R)")
    plt.grid(True)
    plt.legend()
    plt.show()

analyze_creutz_P()

# %%
def analyze_lattice_spacing():
    if not 'calc' in globals():
        print("Calculator not initialized. Please run previous cells.")
        return

    rs = []
    a_vals = []
    a_errs = []
    
    sigma_val = 440.0 # MeV

    print(f"Calculating Lattice Spacing a (assuming sqrt(sigma)={sigma_val} MeV):")
    for R in range(2, 17, 2):
        try:
            # Calculate a using the new calculator method
            a_var = calc.get_variable("a_creutz", R=R, sigma_sqrt_MeV=sigma_val)
            val = a_var.get()
            err = a_var.err()
            
            if val is not None and not np.isnan(val):
                print(f"R={R}: a = {val:.4f} +/- {err:.4f} fm")
                rs.append(R)
                a_vals.append(val)
                a_errs.append(err if err is not None else 0.0)
            else:
                print(f"R={R}: Result is NaN (likely P(R) out of bounds)")
        except Exception as e:
            # Usually happens if Wilson loops are missing for large R
            pass 
            
    if not rs:
        print("No lattice spacing values calculated.")
        return

    # Plot
    plt.figure(figsize=(8, 6))
    plt.errorbar(rs, a_vals, yerr=a_errs, fmt='o-', capsize=5, label=f'a from P(R)')
    
    title_str = rf"Lattice Spacing a (assuming $\sqrt{{\sigma}}={sigma_val}$ MeV)"
    if metro_params:
         title_str += f"\n(beta={metro_params.beta}, L0={metro_params.L0}, eps1={metro_params.epsilon1})"
    plt.title(title_str)
    
    plt.xlabel("R (lattice units)")
    plt.ylabel("a [fm]")
    plt.grid(True)
    plt.legend()
    plt.show()

analyze_lattice_spacing()

# %%
# Plotting the distribution of bootstrap results for a specific R
# Configure R via r_plot and choose the quantity to visualize.

r_plot = 10  # default R to inspect (even R recommended for P(R) and a_creutz)

# Helper to collect bootstrap samples for different quantities at fixed R
def _get_bootstrap_for_R(R: int, quantity: str = "P(R)", sigma_sqrt_MeV: float = 440.0, t_min: int = 1):
    if 'calc' not in globals() or calc is None:
        print("Calculator not initialized. Please run the setup cells above.")
        return None, None

    try:
        if quantity == "P(R)":
            if R % 2 != 0:
                print("P(R) requires even R. Adjust R or choose a different quantity.")
                return None, None
            var = calc.get_variable("creutz_P", R=R)
            label = f"P(R={R})"
        elif quantity == "a_creutz":
            if R % 2 != 0:
                print("a_creutz from P(R) requires even R. Adjust R or choose a different quantity.")
                return None, None
            var = calc.get_variable("a_creutz", R=R, sigma_sqrt_MeV=sigma_sqrt_MeV)
            label = f"a_creutz(R={R}) [fm]"
        elif quantity == "V(R)":
            var = calc.get_variable("V_R", R=R, t_min=t_min)
            label = f"V(R={R})"
        else:
            print(f"Unknown quantity '{quantity}'.")
            return None, None
    except Exception as e:
        print(f"Failed to retrieve {quantity} for R={R}: {e}")
        return None, None

    boots = var.bootstrap()
    if boots is None or len(boots) == 0:
        print(f"No bootstrap samples available for {label}.")
        return None, None

    arr = np.asarray(boots, dtype=float)
    arr = arr[np.isfinite(arr)]
    if arr.size == 0:
        print(f"Bootstrap samples for {label} are all non-finite.")
        return None, None

    return arr, label


def plot_bootstrap_distribution(R: int | None = None, quantity: str = "P(R)", bins: int = 30, sigma_sqrt_MeV: float = 440.0, t_min: int = 1):
    R = int(r_plot if R is None else R)
    data, label = _get_bootstrap_for_R(R, quantity=quantity, sigma_sqrt_MeV=sigma_sqrt_MeV, t_min=t_min)
    if data is None:
        return

    mean = float(np.mean(data))
    std = float(np.std(data))
    q16, q50, q84 = np.percentile(data, [16, 50, 84])

    plt.figure(figsize=(8, 5))
    plt.hist(data, bins=bins, alpha=0.75, edgecolor='k', density=True, label=f"{label} bootstraps")
    plt.axvline(mean, color='r', linestyle='--', linewidth=2, label=f"mean = {mean:.4g}")
    plt.axvspan(mean - std, mean + std, color='r', alpha=0.15, label=f"±1σ ({std:.2g})")

    title = f"Bootstrap distribution for {label}"
    if 'metro_params' in globals() and metro_params:
        title += f"\n(beta={metro_params.beta}, L0={metro_params.L0}, eps1={metro_params.epsilon1})"
    plt.title(title)
    plt.xlabel(label)
    plt.ylabel("Density")
    plt.grid(True, alpha=0.3)
    plt.legend()
    plt.tight_layout()
    plt.show()

    print(f"Summary for {label} (bins={bins}):")
    print(f"  mean = {mean:.6g}, std = {std:.6g}")
    print(f"  median = {q50:.6g}, 16%-84% = [{q16:.6g}, {q84:.6g}]")


# Quick static plot for current r_plot
plot_bootstrap_distribution(R=r_plot, quantity="P(R)", bins=30)

# Optional: make it interactive
try:
    widgets.interact(
        plot_bootstrap_distribution,
        R=widgets.IntSlider(min=2, max=20, step=2, value=int(r_plot), description='R'),
        quantity=widgets.Dropdown(options=["P(R)", "a_creutz", "V(R)"], value="P(R)", description='Quantity'),
        bins=widgets.IntSlider(min=10, max=100, step=2, value=30, description='Bins'),
        sigma_sqrt_MeV=widgets.FloatSlider(min=300.0, max=600.0, step=5.0, value=440.0, description='√σ [MeV]'),
        t_min=widgets.IntSlider(min=1, max=6, step=1, value=1, description='t_min')
    )
except Exception:
    # If widgets are unavailable, the static plot above will still render
    pass
